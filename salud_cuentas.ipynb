# %%
import pandas as pd
from pathlib import Path


def read_csv_with_fallback(*candidates):
    for candidate in candidates:
        path = Path(candidate)
        if path.exists():
            print(f"Loading {path}")
            return pd.read_csv(path)
    raise FileNotFoundError(f"None of these files were found: {candidates}")


def read_optional_csv(*candidates, required_columns=None):
    required_columns = set(required_columns or [])
    for candidate in candidates:
        path = Path(candidate)
        if not path.exists():
            continue
        print(f"Loading {path}")
        df = pd.read_csv(path)
        missing = sorted(required_columns - set(df.columns))
        if missing:
            print(f"Skipping {path} because it is missing columns: {missing}")
            continue
        return df
    return pd.DataFrame(columns=sorted(required_columns))


# Read weekly source CSV files
# Prefer canonical *_weekly exports, with fallback to legacy names where needed.
df_billing = read_csv_with_fallback(
    'data/session_billing_events_weekly.csv',
    'data/session_billing_events.csv',
)
df_dau = read_csv_with_fallback(
    'data/logsM.ai_daily_active_users_weekly.csv',
    'data/logsM.ai_daily_active_users.csv',
)
df_workflow = read_csv_with_fallback(
    'data/builder.workflow_executions_logs_weekly.csv',
    'data/builder.workflow_executions_logs.csv',
)
df_signups = read_csv_with_fallback('data/signups_weekly.csv')
df_connect = read_csv_with_fallback('data/connect_licenses_weekly.csv')

# KYC by stage/status exported from identity
try:
    df_kyc = read_csv_with_fallback('data/kyc_steps_weekly.csv')
except FileNotFoundError:
    df_kyc = pd.DataFrame(
        columns=['companyId', 'companyName', 'week_end_sunday', 'stepName', 'status', 'kyc_steps_count']
    )

# Weekly metrics for government entity checks + HIL exported from identity
try:
    df_kyc_hil_gov = read_csv_with_fallback('data/kyc_hil_government_weekly.csv')
except FileNotFoundError:
    df_kyc_hil_gov = pd.DataFrame(
        columns=[
            'companyId',
            'companyName',
            'week_end_sunday',
            'kyc_sessions_total',
            'gov_validated',
            'gov_not_validated',
            'hil_doccheck_total',
            'hil_doccheck_approved',
            'hil_doccheck_disapproved',
            'hil_liveness_total',
            'hil_liveness_approved',
            'hil_liveness_disapproved',
            'hil_facematch_total',
            'hil_facematch_approved',
            'hil_facematch_disapproved',
        ]
    )

marketplace_required_columns = {
    'userId',
    'userType',
    'installedByUserId',
    'app_name',
    'installed_at',
}
df_marketplace = read_optional_csv(
    'data/marketplace_installations_events.csv',
    '../product_usage/marketplace/marketplace_installations_events.csv',
    '../product_usage/marketplace/installed_apps_events.csv',
    required_columns=marketplace_required_columns,
)
df_marketplace_mapping = read_optional_csv(
    'data/user_to_companyid_mapping.csv',
    '../product_usage/marketplace/user_to_companyid_mapping.csv',
    required_columns={'userId', 'companyId'},
)

print("df_billing:", df_billing.shape)
print(df_billing.head())
print("\ndf_dau:", df_dau.shape)
print(df_dau.head())
print("\ndf_workflow:", df_workflow.shape)
print(df_workflow.head())
print("\ndf_signups:", df_signups.shape)
print(df_signups.head())
print("\ndf_connect:", df_connect.shape)
print(df_connect.head())
print("\ndf_kyc:", df_kyc.shape)
print(df_kyc.head())
print("\ndf_kyc_hil_gov:", df_kyc_hil_gov.shape)
print(df_kyc_hil_gov.head())
print("\ndf_marketplace:", df_marketplace.shape)
print(df_marketplace.head())
print("\ndf_marketplace_mapping:", df_marketplace_mapping.shape)
print(df_marketplace_mapping.head())
# Out:
# Loading data\session_billing_events_weekly.csv
# Loading data\logsM.ai_daily_active_users_weekly.csv
# Loading data\builder.workflow_executions_logs_weekly.csv
# Loading data\signups_weekly.csv
# Loading data\connect_licenses_weekly.csv
# Loading data\kyc_steps_weekly.csv
# Loading data\kyc_hil_government_weekly.csv
# Loading data\marketplace_installations_events.csv
# Loading ..\product_usage\marketplace\user_to_companyid_mapping.csv
# df_billing: (6002, 5)
#    companyId week_end_sunday conversationType  event_count  billable_count
# 0          1      2025-06-29          UTILITY            4               4
# 1          1      2025-07-06   MARKETING_LITE          967             967
# 2          1      2025-07-06          UTILITY          305             279
# 3          1      2025-07-13   MARKETING_LITE         9398            9398
# 4          1      2025-07-13          UTILITY          493             464
#
# df_dau: (7592, 4)
# ...

# %%
# Normalize weekly keys and billing categories
for _df in [df_billing, df_dau, df_workflow, df_connect, df_kyc, df_kyc_hil_gov]:
    if 'week_end_sunday' in _df.columns:
        _df['week_end_sunday'] = pd.to_datetime(_df['week_end_sunday']).dt.strftime('%Y-%m-%d')

df_signups['week_end_sunday'] = pd.to_datetime(df_signups['week_end_sunday']).dt.strftime('%Y-%m-%d')

# Build connect plan-level columns from the new billing plan tier fields.
connect_plan_label = None
for plan_col in ['plan_tier_display_name', 'plan_tier_name', 'product_name']:
    if plan_col in df_connect.columns:
        connect_plan_label = df_connect[plan_col].fillna('').astype(str).str.strip()
        connect_plan_label = connect_plan_label.mask(connect_plan_label == '', 'Unknown Plan')
        break

if connect_plan_label is not None:
    df_connect = df_connect.copy()
    df_connect['connect_plan_label'] = connect_plan_label

    connect_pivot = df_connect.pivot_table(
        index=['companyId', 'week_end_sunday'],
        columns='connect_plan_label',
        values='connect_licenses',
        aggfunc='sum',
        fill_value=0
    ).reset_index()

    def _slug_plan_name(name):
        cleaned = ''.join(ch.lower() if ch.isalnum() else '_' for ch in str(name)).strip('_')
        while '__' in cleaned:
            cleaned = cleaned.replace('__', '_')
        return cleaned or 'unknown_plan'

    plan_cols_original = [c for c in connect_pivot.columns if c not in ['companyId', 'week_end_sunday']]
    rename_map = {c: f"connect_plan_{_slug_plan_name(c)}" for c in plan_cols_original}
    connect_pivot = connect_pivot.rename(columns=rename_map)

    plan_cols_slug = list(rename_map.values())
    connect_pivot['connect_licenses'] = connect_pivot[plan_cols_slug].sum(axis=1)

    def _build_plan_list(row):
        active = []
        for original_name, slug_col in rename_map.items():
            if row.get(slug_col, 0) > 0:
                active.append(str(original_name))
        return ', '.join(sorted(active))

    connect_pivot['connect_plan_list'] = connect_pivot.apply(_build_plan_list, axis=1)
    df_connect = connect_pivot

# Build KYC columns by stage+status and stage totals
if not df_kyc.empty:
    df_kyc['stepName'] = df_kyc['stepName'].astype(str).str.strip().str.lower()
    df_kyc['status'] = df_kyc['status'].astype(str).str.strip().str.lower()
    df_kyc['kyc_steps_count'] = pd.to_numeric(df_kyc['kyc_steps_count'], errors='coerce').fillna(0)
    df_kyc = df_kyc[
        (df_kyc['stepName'] != '')
        & (df_kyc['status'] != '')
        & (df_kyc['stepName'].str.lower() != 'nan')
        & (df_kyc['status'].str.lower() != 'nan')
    ].copy()

    def _slug_kyc_text(name):
        cleaned = ''.join(ch.lower() if ch.isalnum() else '_' for ch in str(name)).strip('_')
        while '__' in cleaned:
            cleaned = cleaned.replace('__', '_')
        return cleaned or 'unknown'

    kyc_status = (
        df_kyc.groupby(['companyId', 'week_end_sunday', 'stepName', 'status'], as_index=False)['kyc_steps_count']
        .sum()
    )
    kyc_status['kyc_col'] = (
        'kyc_' + kyc_status['stepName'].map(_slug_kyc_text) + '_' + kyc_status['status'].map(_slug_kyc_text)
    )

    kyc_status_pivot = kyc_status.pivot_table(
        index=['companyId', 'week_end_sunday'],
        columns='kyc_col',
        values='kyc_steps_count',
        aggfunc='sum',
        fill_value=0
    ).reset_index()

    kyc_stage = (
        kyc_status.groupby(['companyId', 'week_end_sunday', 'stepName'], as_index=False)['kyc_steps_count']
        .sum()
    )
    kyc_stage['stage_col'] = 'kyc_' + kyc_stage['stepName'].map(_slug_kyc_text) + '_total'

    kyc_stage_pivot = kyc_stage.pivot_table(
        index=['companyId', 'week_end_sunday'],
        columns='stage_col',
        values='kyc_steps_count',
        aggfunc='sum',
        fill_value=0
    ).reset_index()

    kyc_total = (
        kyc_status.groupby(['companyId', 'week_end_sunday'], as_index=False)['kyc_steps_count']
        .sum()
        .rename(columns={'kyc_steps_count': 'kyc_total'})
    )

    df_kyc = kyc_status_pivot.merge(kyc_stage_pivot, on=['companyId', 'week_end_sunday'], how='outer')
    df_kyc = df_kyc.merge(kyc_total, on=['companyId', 'week_end_sunday'], how='left')
else:
    df_kyc = pd.DataFrame(
        columns=[
            'companyId',
            'week_end_sunday',
            'kyc_document_check_total',
            'kyc_liveness_total',
            'kyc_facematch_total',
            'kyc_total',
        ]
    )

# Normalize and aggregate company-week HIL/government metrics
hil_gov_numeric_cols = [
    'kyc_sessions_total',
    'gov_validated',
    'gov_not_validated',
    'hil_doccheck_total',
    'hil_doccheck_approved',
    'hil_doccheck_disapproved',
    'hil_liveness_total',
    'hil_liveness_approved',
    'hil_liveness_disapproved',
    'hil_facematch_total',
    'hil_facematch_approved',
    'hil_facematch_disapproved',
]
for col in hil_gov_numeric_cols:
    if col in df_kyc_hil_gov.columns:
        df_kyc_hil_gov[col] = pd.to_numeric(df_kyc_hil_gov[col], errors='coerce').fillna(0)
    else:
        df_kyc_hil_gov[col] = 0

if not df_kyc_hil_gov.empty:
    df_kyc_hil_gov = (
        df_kyc_hil_gov
        .groupby(['companyId', 'week_end_sunday'], as_index=False)[hil_gov_numeric_cols]
        .sum()
    )
else:
    df_kyc_hil_gov = pd.DataFrame(
        columns=['companyId', 'week_end_sunday'] + hil_gov_numeric_cols
    )

# Build weekly marketplace installation columns from event-level export
marketplace_prefix = 'marketplace_app_'

def _slug_marketplace_app(name):
    cleaned = ''.join(ch.lower() if ch.isalnum() else '_' for ch in str(name)).strip('_')
    while '__' in cleaned:
        cleaned = cleaned.replace('__', '_')
    return cleaned or 'unknown_app'

marketplace_long_cols = ['companyId', 'week_end_sunday', 'app_name', 'marketplace_install_count']
df_marketplace_weekly_long = pd.DataFrame(columns=marketplace_long_cols)
df_marketplace_weekly = pd.DataFrame(columns=['companyId', 'week_end_sunday', 'marketplace_install_total'])

if not df_marketplace.empty and not df_marketplace_mapping.empty:
    df_marketplace = df_marketplace.copy()
    df_marketplace_mapping = df_marketplace_mapping.copy()

    for col in ['userId', 'installedByUserId']:
        if col in df_marketplace.columns:
            df_marketplace[col] = df_marketplace[col].astype('string').str.strip()

    if 'mapping_user_id' in df_marketplace.columns:
        df_marketplace['mapping_user_id'] = df_marketplace['mapping_user_id'].astype('string').str.strip()
    else:
        df_marketplace['mapping_user_id'] = df_marketplace['userId']
        organization_mask = df_marketplace['userType'].astype('string').str.upper().eq('ORGANIZATION')
        df_marketplace.loc[organization_mask, 'mapping_user_id'] = df_marketplace.loc[organization_mask, 'installedByUserId']
        df_marketplace['mapping_user_id'] = df_marketplace['mapping_user_id'].astype('string').str.strip()

    df_marketplace['app_name'] = df_marketplace['app_name'].fillna('').astype(str).str.strip()
    df_marketplace['installed_at'] = pd.to_datetime(df_marketplace['installed_at'], errors='coerce')
    df_marketplace = df_marketplace[
        df_marketplace['mapping_user_id'].notna()
        & (df_marketplace['mapping_user_id'] != '')
        & df_marketplace['installed_at'].notna()
        & (df_marketplace['app_name'] != '')
    ].copy()

    df_marketplace_mapping['userId'] = df_marketplace_mapping['userId'].astype('string').str.strip()
    df_marketplace_mapping['companyId'] = pd.to_numeric(df_marketplace_mapping['companyId'], errors='coerce')
    df_marketplace_mapping = df_marketplace_mapping[df_marketplace_mapping['companyId'].notna()].copy()
    df_marketplace_mapping['companyId'] = df_marketplace_mapping['companyId'].astype('Int64')

    df_marketplace = df_marketplace.merge(
        df_marketplace_mapping.rename(columns={'userId': 'mapping_user_id'}),
        on='mapping_user_id',
        how='left'
    )
    df_marketplace = df_marketplace[df_marketplace['companyId'].notna()].copy()
    df_marketplace['companyId'] = df_marketplace['companyId'].astype('Int64')
    df_marketplace['week_end_sunday'] = (
        df_marketplace['installed_at'].dt.normalize()
        + pd.to_timedelta(6 - df_marketplace['installed_at'].dt.weekday, unit='D')
    ).dt.strftime('%Y-%m-%d')

    df_marketplace_weekly_long = (
        df_marketplace.groupby(['companyId', 'week_end_sunday', 'app_name'], as_index=False)
        .size()
        .rename(columns={'size': 'marketplace_install_count'})
        .sort_values(['week_end_sunday', 'companyId', 'app_name'])
    )
    df_marketplace_weekly_long['marketplace_col'] = (
        marketplace_prefix + df_marketplace_weekly_long['app_name'].map(_slug_marketplace_app)
    )

    df_marketplace_weekly = df_marketplace_weekly_long.pivot_table(
        index=['companyId', 'week_end_sunday'],
        columns='marketplace_col',
        values='marketplace_install_count',
        aggfunc='sum',
        fill_value=0
    ).reset_index()
    df_marketplace_weekly.columns.name = None

    marketplace_app_cols = [
        c for c in df_marketplace_weekly.columns
        if c.startswith(marketplace_prefix)
    ]
    if marketplace_app_cols:
        df_marketplace_weekly['marketplace_install_total'] = df_marketplace_weekly[marketplace_app_cols].sum(axis=1)
    else:
        df_marketplace_weekly['marketplace_install_total'] = 0

    unmatched_installs = int(df_marketplace['companyId'].isna().sum())
    print(f"Matched marketplace installs: {len(df_marketplace):,}")
    print(f"Unmatched marketplace installs after mapping: {unmatched_installs:,}")
else:
    print('Marketplace event export or user/company mapping not found; skipping marketplace merge.')

# Merge MARKETING_LITE into MARKETING
if 'conversationType' in df_billing.columns:
    df_billing['conversationType'] = df_billing['conversationType'].replace({
        'MARKETING_LITE': 'MARKETING'
    })

# Pivot billing data to have whatsapp categories as separate columns
df_billing_pivot = df_billing.pivot_table(
    index=['companyId', 'week_end_sunday'],
    columns='conversationType',
    values='billable_count',
    aggfunc='sum',
    fill_value=0
).reset_index()

# Ensure expected WhatsApp columns exist
for col in ['MARKETING', 'UTILITY', 'AUTHENTICATION']:
    if col not in df_billing_pivot.columns:
        df_billing_pivot[col] = 0

# Flatten columns and keep only expected set
df_billing_pivot.columns.name = None
df_billing_pivot = df_billing_pivot[['companyId', 'week_end_sunday', 'MARKETING', 'UTILITY', 'AUTHENTICATION']]

print("df_billing_pivot:", df_billing_pivot.shape)
print(df_billing_pivot.columns.tolist())
print("\ndf_marketplace_weekly:", df_marketplace_weekly.shape)
print(df_marketplace_weekly.head())
print("\ndf_marketplace_weekly_long:", df_marketplace_weekly_long.shape)
print(df_marketplace_weekly_long.head())
df_billing_pivot.head()
# Out:
# Matched marketplace installs: 502
# Unmatched marketplace installs after mapping: 0
# df_billing_pivot: (3775, 5)
# ['companyId', 'week_end_sunday', 'MARKETING', 'UTILITY', 'AUTHENTICATION']
#
# df_marketplace_weekly: (307, 66)
#    companyId week_end_sunday  marketplace_app_2captcha  marketplace_app_adalo  \
# 0          1      2025-11-09                         0                      0
# 1          5      2026-01-11                         0                      0
# 2          5      2026-01-18                         0                      0
# 3          5      2026-02-15                         0                      0
# 4          5      2026-03-01                         0                      0
#
#    marketplace_app_add_to_calendar_pro  marketplace_app_aerisweather  \
# 0                                    0                             0
# 1                                    0                             0
# ...

# %%
# Merge weekly company-level datasets
company_keys = ['companyId', 'week_end_sunday']

df_merged = df_workflow.merge(df_billing_pivot, on=company_keys, how='outer')
df_merged = df_merged.merge(df_dau, on=company_keys, how='outer')
df_merged = df_merged.merge(df_connect, on=company_keys, how='outer')
df_merged = df_merged.merge(df_kyc, on=company_keys, how='outer')
df_merged = df_merged.merge(df_kyc_hil_gov, on=company_keys, how='outer')
df_merged = df_merged.merge(df_marketplace_weekly, on=company_keys, how='outer')

# Join weekly signup totals to all company rows in the same week
# (app should aggregate signups from unique week rows to avoid double-counting)
df_merged = df_merged.merge(df_signups, on='week_end_sunday', how='left')

# Drop future weeks: keep only data up to last completed Sunday
# Example: if today is Thu 2026-03-05, cutoff is Sun 2026-03-01.
today = pd.Timestamp.today().normalize()
last_completed_week_end = today - pd.Timedelta(days=today.weekday() + 1)

df_merged['week_end_sunday'] = pd.to_datetime(df_merged['week_end_sunday'], errors='coerce')
df_merged = df_merged[df_merged['week_end_sunday'].notna()]
df_merged = df_merged[df_merged['week_end_sunday'] <= last_completed_week_end].copy()
df_merged['week_end_sunday'] = df_merged['week_end_sunday'].dt.strftime('%Y-%m-%d')

# Canonical numeric columns
plan_cols = [c for c in df_merged.columns if c.startswith('connect_plan_') and c != 'connect_plan_list']
kyc_cols = [c for c in df_merged.columns if c.startswith('kyc_')]
marketplace_cols = [c for c in df_merged.columns if c.startswith('marketplace_app_')]
numeric_cols = [
    'execution_count', 'dau_count', 'unique_users_count',
    'MARKETING', 'UTILITY', 'AUTHENTICATION',
    'connect_licenses', 'marketplace_install_total',
    'signups', 'self_service', 'enterprise', 'other_plans'
] + plan_cols + kyc_cols + marketplace_cols
for col in numeric_cols:
    if col in df_merged.columns:
        df_merged[col] = pd.to_numeric(df_merged[col], errors='coerce').fillna(0)

# Keep companyName stable where available
if 'companyName' in df_merged.columns:
    df_merged['companyName'] = df_merged['companyName'].fillna('Unknown')

if 'connect_plan_list' in df_merged.columns:
    df_merged['connect_plan_list'] = df_merged['connect_plan_list'].fillna('')

# Sort for downstream charting
df_merged = df_merged.sort_values(['week_end_sunday', 'companyId'])

print("df_merged:", df_merged.shape)
print(f"Unique companies: {df_merged['companyId'].nunique()}")
print(f"Unique weeks: {df_merged['week_end_sunday'].nunique()}")
print("Columns:", df_merged.columns.tolist())
df_merged.head(10)
# Out:
# df_merged: (13346, 115)
# Unique companies: 1232
# Unique weeks: 65
# ...

# %%
# Save the canonical weekly merged dataframe for Streamlit
df_merged.to_csv('data/merged_weekly_data.csv', index=False)
print("Saved merged data to data/merged_weekly_data.csv")

if not df_marketplace_weekly_long.empty:
    df_marketplace_weekly_long.to_csv('data/marketplace_installations_weekly_long.csv', index=False)
    print("Saved marketplace weekly long data to data/marketplace_installations_weekly_long.csv")
# Out:
# Saved merged data to data/merged_weekly_data.csv
# Saved marketplace weekly long data to data/marketplace_installations_weekly_long.csv

# %%
df_merged
# Out:
#        execution_count  companyId                   companyName  \
# 52                33.0          5                        DevLab
# 228                0.0         35                       Unknown
# 324            11091.0         54                         Pycca
# 472            12125.0         95                         Veris
# 735               26.0        124                   GEA Ecuador
# ...                ...        ...                           ...
# 14179              0.0       4872                       Unknown
# 14183              6.0       4879                       Monovco
# 14184              0.0       4882                       Unknown
# 14188              3.0       4883  Entrenador Virtual Niljunior
# 14189              2.0       4884               cuyabros online
#
#       week_end_sunday  MARKETING  UTILITY  AUTHENTICATION  dau_count  \
# 52         2025-01-05        0.0      0.0             0.0        1.0
# ...
